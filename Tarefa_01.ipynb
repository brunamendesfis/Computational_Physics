# %% [markdown]
# # Tarefa:
# Achar o mínimo das funções abaixo usando o método do gradiente descendente
#
# 1) f(x) = x² - 1 e x_0 = 3 \
# montar o gráfico dessa função. com as raízes e mostrando os passos com diferentes valores de alpha
#
# 2) pegar a função que o professor forneceu, escolher as raízes e mostrar os passos mostrando o alpha
# Entrega: ideal entregar na terça, caso não seja possível, entregar até no máximo quinta-feira

# %% [markdown]
# Definir a função \
# Derivar a função

# %%
import numpy as np
import matplotlib.pyplot as plt

def funcao(x):
    y = x**2 - 1
    return y

def derivada(x):
    grad = 2*x
    return grad

def Delta(alpha, grad):
    D = - alpha*grad 
    return D

# %%
# Definindo valores de x
x = np.linspace(-2, 2, 400)

y = x**2 - 1

# %%
plt.title("Função y(x) = x² - 1")
plt.grid(True)
plt.plot(x, y)
plt.show()

# %%
x_0 = 3
alpha = 0.1

# %%
derivada(x_0)
# Out:
# 6

# %%
x_1 = x_0 - alpha * derivada(x_0)

# %%
xs = [x_0]
xs.append(xs[-1] - alpha * derivada(xs[-1]))
xs.append(xs[-1] - alpha * derivada(xs[-1]))

print(xs)
# Out:
# [3, 2.4, 1.92]

# %%
# Linha horizontal em y=0
#plt.axhline(y=0, color='black', linestyle='--', linewidth=0.8)
